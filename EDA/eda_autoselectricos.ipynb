# %%
#Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Leemos el dataset de autos electricos
df = pd.read_csv("MY2012-2024 Battery Electric Vehicles.csv")
df
# Out:
#      Model year        Make               Model                 Vehicle class  \
# 0          2012  Mitsubishi              i-MiEV                    Subcompact
# 1          2012      Nissan                LEAF                      Mid-size
# 2          2013        Ford      Focus Electric                       Compact
# 3          2013  Mitsubishi              i-MiEV                    Subcompact
# 4          2013      Nissan                LEAF                      Mid-size
# ..          ...         ...                 ...                           ...
# 640        2024  Volkswagen      ID.4 AWD Pro S  Sport utility vehicle: Small
# 641        2024       Volvo        C40 Recharge  Sport utility vehicle: Small
# 642        2024       Volvo   C40 Recharge Twin  Sport utility vehicle: Small
# 643        2024       Volvo       XC40 Recharge  Sport utility vehicle: Small
# 644        2024       Volvo  XC40 Recharge Twin  Sport utility vehicle: Small
#
# ...

# %%
df.describe(include="all")
# Out:
#          Model year   Make    Model                    Vehicle class  \
# count    645.000000    645      645                              645
# unique          NaN     31      357                                9
# top             NaN  Tesla  Bolt EV  Sport utility vehicle: Standard
# freq            NaN    149        7                              130
# mean    2021.446512    NaN      NaN                              NaN
# std        2.857757    NaN      NaN                              NaN
# min     2012.000000    NaN      NaN                              NaN
# 25%     2020.000000    NaN      NaN                              NaN
# 50%     2023.000000    NaN      NaN                              NaN
# 75%     2024.000000    NaN      NaN                              NaN
# max     2024.000000    NaN      NaN                              NaN
#
#         Motor (kW) Transmission Fuel type  City (kWh/100 km)  \
# count   645.000000          645       645         645.000000
# ...

# %%
#Vemos si hay valores nulos
df.isna().mean()
# Out:
# Model year               0.000000
# Make                     0.000000
# Model                    0.000000
# Vehicle class            0.000000
# Motor (kW)               0.000000
# Transmission             0.000000
# Fuel type                0.000000
# City (kWh/100 km)        0.000000
# Highway (kWh/100 km)     0.000000
# Combined (kWh/100 km)    0.000000
# City (Le/100 km)         0.000000
# Highway (Le/100 km)      0.000000
# Combined (Le/100 km)     0.000000
# Range (km)               0.000000
# CO2 emissions (g/km)     0.000000
# CO2 rating               0.052713
# Smog rating              0.094574
# Recharge time (h)        0.000000
# dtype: float64

# %% [markdown]
# No hay una gran cantidad de datos nulos

# %%
#Verificamos duplicados
df.duplicated().mean()
# Out:
# 0.0

# %% [markdown]
# No hay duplicados

# %%
df.head()
# Out:
#    Model year        Make           Model Vehicle class  Motor (kW)  \
# 0        2012  Mitsubishi          i-MiEV    Subcompact          49
# 1        2012      Nissan            LEAF      Mid-size          80
# 2        2013        Ford  Focus Electric       Compact         107
# 3        2013  Mitsubishi          i-MiEV    Subcompact          49
# 4        2013      Nissan            LEAF      Mid-size          80
#
#   Transmission Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  \
# 0           A1         B               16.9                  21.4
# 1           A1         B               19.3                  23.0
# 2           A1         B               19.0                  21.1
# 3           A1         B               16.9                  21.4
# 4           A1         B               19.3                  23.0
#
#    Combined (kWh/100 km)  City (Le/100 km)  Highway (Le/100 km)  \
# 0                   18.7               1.9                  2.4
# ...

# %%
#Creamos una función para no repetir codigo que nos sirva para agrupar y hacer el promedio de la columna que seleccionamos
def agrupar_y_promedio(columna_a_agrupar, columna_a_modificar):
    #Agrupamos y aplicamos la funcion
    agrupado = df.groupby(columna_a_agrupar)[columna_a_modificar].mean().reset_index()
    #Ordenamos los valores por la columna a la que le aplicamos la funcion y reseteamos los indices
    agrupado = agrupado.sort_values(by=columna_a_modificar).reset_index(drop=True)
    return agrupado

# %%
#Aplicamos la función para agrupar por tamaño de motor y cuantos kw consume en 100km
km_ciudad = agrupar_y_promedio("Motor (kW)", "City (kWh/100 km)")
km_ciudad
# Out:
#      Motor (kW)  City (kWh/100 km)
# 0            88          13.700000
# 1           111          13.700000
# 2           192          15.133333
# 3           168          15.177778
# 4           330          15.300000
# ..          ...                ...
# 100         650          29.561111
# 101         381          30.200000
# 102         370          31.216667
# 103         600          36.850000
# 104         428          38.750000
#
# [105 rows x 2 columns]

# %%
#Hacemos un top10 de los que menos consumen
km_ciudad_top10 = km_ciudad.head(10)
km_ciudad_top10
# Out:
#    Motor (kW)  City (kWh/100 km)
# 0          88          13.700000
# 1         111          13.700000
# 2         192          15.133333
# 3         168          15.177778
# 4         330          15.300000
# 5         211          15.360000
# 6         191          15.400000
# 7         202          15.466667
# 8         293          15.525000
# 9         276          15.650000

# %%
#Hacemos el grafico
sns.barplot(data = km_ciudad_top10, x= "Motor (kW)", y= "City (kWh/100 km)", order=km_ciudad_top10["Motor (kW)"])
plt.show()

# %%
#Los que mas consumen
km_ciudad_bottom10 = km_ciudad.tail(10)
km_ciudad_bottom10 = km_ciudad_bottom10.sort_values(by="City (kWh/100 km)", ascending=False).reset_index(drop=True)
km_ciudad_bottom10
# Out:
#    Motor (kW)  City (kWh/100 km)
# 0         428          38.750000
# 1         600          36.850000
# 2         370          31.216667
# 3         381          30.200000
# 4         650          29.561111
# 5         460          28.713333
# 6         260          28.375000
# 7         485          28.275000
# 8         484          28.150000
# 9         360          28.014286

# %%
#Hacemos el grafico
sns.barplot(data = km_ciudad_bottom10, x= "Motor (kW)", y= "City (kWh/100 km)", order=km_ciudad_bottom10["Motor (kW)"])
plt.show()

# %%
df.head()
# Out:
#    Model year        Make           Model Vehicle class  Motor (kW)  \
# 0        2012  Mitsubishi          i-MiEV    Subcompact          49
# 1        2012      Nissan            LEAF      Mid-size          80
# 2        2013        Ford  Focus Electric       Compact         107
# 3        2013  Mitsubishi          i-MiEV    Subcompact          49
# 4        2013      Nissan            LEAF      Mid-size          80
#
#   Transmission Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  \
# 0           A1         B               16.9                  21.4
# 1           A1         B               19.3                  23.0
# 2           A1         B               19.0                  21.1
# 3           A1         B               16.9                  21.4
# 4           A1         B               19.3                  23.0
#
#    Combined (kWh/100 km)  City (Le/100 km)  Highway (Le/100 km)  \
# 0                   18.7               1.9                  2.4
# ...

# %%
#Usamos la funcino para ver que motores son los que pueden recorrer mas km
motor_rango = agrupar_y_promedio("Motor (kW)", "Range (km)")
motor_rango
# Out:
#      Motor (kW)  Range (km)
# 0            60   92.500000
# 1            49  100.000000
# 2            35  109.000000
# 3           104  131.000000
# 4            80  140.428571
# ..          ...         ...
# 100         930  687.000000
# 101         783  718.000000
# 102         829  742.000000
# 103         611  785.000000
# 104         696  805.500000
#
# [105 rows x 2 columns]

# %%
#Hacemos el top10 de los que menos rango tienen y lo graficamos
motor_rango_menoskm = pd.DataFrame(motor_rango.head(10))
sns.barplot(data = motor_rango_menoskm, x= "Motor (kW)", y= "Range (km)", order=motor_rango_menoskm["Motor (kW)"])
plt.show()

# %%
#Hacemos el top10 de los que mas rango tienen y lo graficamos
motor_rango_maskm = pd.DataFrame(motor_rango.tail(10))
motor_rango_maskm = motor_rango_maskm.sort_values(by="Range (km)", ascending=False).reset_index(drop=True)
sns.barplot(data = motor_rango_maskm, x= "Motor (kW)", y= "Range (km)", order=motor_rango_maskm["Motor (kW)"])
plt.show()

# %%
df.head()
# Out:
#    Model year        Make           Model Vehicle class  Motor (kW)  \
# 0        2012  Mitsubishi          i-MiEV    Subcompact          49
# 1        2012      Nissan            LEAF      Mid-size          80
# 2        2013        Ford  Focus Electric       Compact         107
# 3        2013  Mitsubishi          i-MiEV    Subcompact          49
# 4        2013      Nissan            LEAF      Mid-size          80
#
#   Transmission Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  \
# 0           A1         B               16.9                  21.4
# 1           A1         B               19.3                  23.0
# 2           A1         B               19.0                  21.1
# 3           A1         B               16.9                  21.4
# 4           A1         B               19.3                  23.0
#
#    Combined (kWh/100 km)  City (Le/100 km)  Highway (Le/100 km)  \
# 0                   18.7               1.9                  2.4
# ...

# %%
#Aplicamos la funcion para agrupar por motor y cuanto tardan en cargarse
promedio_carga = agrupar_y_promedio("Motor (kW)", "Recharge time (h)")
promedio_carga
# Out:
#      Motor (kW)  Recharge time (h)
# 0            60           3.000000
# 1            88           4.000000
# 2            81           4.400000
# 3           107           4.766667
# 4           135           5.111111
# ..          ...                ...
# 100         494          14.428571
# 101         750          14.571429
# 102         282          14.850000
# 103         149          15.200000
# 104         414          18.000000
#
# [105 rows x 2 columns]

# %%
#Los 10 motores que menos tardan en cargarse y lo graficamos
promedio_carga_menorcarga = promedio_carga.head(10)
sns.barplot(data = promedio_carga_menorcarga, x= "Motor (kW)", y= "Recharge time (h)", order=promedio_carga_menorcarga["Motor (kW)"])
plt.show()

# %%
#Los 10 motores que mas tardan en cargarse y lo graficamos
promedio_carga_mayorcarga = promedio_carga.tail(10)
promedio_carga_mayorcarga = promedio_carga_mayorcarga.sort_values(by="Recharge time (h)", ascending=False).reset_index(drop=True)
sns.barplot(data = promedio_carga_mayorcarga, x= "Motor (kW)", y= "Recharge time (h)", order=promedio_carga_mayorcarga["Motor (kW)"])
plt.show()

# %%
""""
Lista de autos permitidos para taxis en NYC
23 Hyundai Ioniq 5 Electric Vehicle
22-23 Kia Niro Electric Vehicle
19-23 Tesla Model 3 RWD Electric Vehicle
19-23 Tesla Model 3 Long Range Electric Vehicle
21-23 Tesla Model Y long Range AWD Electric Vehicle
23 Toyota bZ4X Electric Vehicle
"""
# Out:
# '"\nLista de autos permitidos para taxis en NYC\n23 Hyundai Ioniq 5 Electric Vehicle\n22-23 Kia Niro Electric Vehicle\n19-23 Tesla Model 3 RWD Electric Vehicle\n19-23 Tesla Model 3 Long Range Electric Vehicle\n21-23 Tesla Model Y long Range AWD Electric Vehicle\n23 Toyota bZ4X Electric Vehicle\n'

# %%
#Filtramos por el modelo del auto
hyundai_ioniq5 = df[(df["Make"] == "Hyundai") & (df["Model"].str.contains("IONIQ 5", case=False, na=False) & (df["Model year"] == 2023))]
hyundai_ioniq5
# Out:
#      Model year     Make                   Model Vehicle class  Motor (kW)  \
# 355        2023  Hyundai  IONIQ 5 Standard Range     Full-size         125
# 356        2023  Hyundai      IONIQ 5 Long Range     Full-size         168
# 357        2023  Hyundai  IONIQ 5 Long Range AWD     Full-size         239
#
#     Transmission Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  \
# 355           A1         B               16.2                  22.4
# 356           A1         B               15.5                  21.7
# 357           A1         B               18.9                  23.5
#
#      Combined (kWh/100 km)  City (Le/100 km)  Highway (Le/100 km)  \
# 355                   19.3               1.9                  2.5
# 356                   18.6               1.8                  2.4
# 357                   21.0               2.1                  2.6
#
#      Combined (Le/100 km)  Range (km)  CO2 emissions (g/km)  CO2 rating   \
# ...

# %%
#Filtramos por el modelo del auto
kia_niro = df[(df["Make"] == "Kia") & (df["Model"].str.contains("Niro", case=False, na=False) & (df["Model year"] > 2021) & (df["Model year"] < 2024))]
kia_niro
# Out:
#      Model year Make    Model         Vehicle class  Motor (kW) Transmission  \
# 264        2022  Kia  Niro EV  Station wagon: Small         150           A1
# 369        2023  Kia  Niro EV  Station wagon: Small         150           A1
#
#     Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  Combined (kWh/100 km)  \
# 264         B               17.0                  20.6                   18.6
# 369         B               16.8                  20.5                   18.6
#
#      City (Le/100 km)  Highway (Le/100 km)  Combined (Le/100 km)  Range (km)  \
# 264               1.9                  2.3                   2.1         385
# 369               1.9                  2.3                   2.1         407
#
#      CO2 emissions (g/km)  CO2 rating   Smog rating  Recharge time (h)
# 264                     0         10.0         10.0                9.5
# 369                     0         10.0         10.0                7.5

# %%
#Filtramos por el modelo del auto
tesla_model3 = df[(df["Make"] == "Tesla") & (df["Model"].str.contains("Model 3 Long|RWD|AWD", case=False, na=False) & (df["Model year"] > 2018) & (df["Model year"] < 2024))]
tesla_model3.head()
# Out:
#      Model year   Make                               Model Vehicle class  \
# 122        2019  Tesla                  Model 3 Long Range      Mid-size
# 123        2019  Tesla              Model 3 Long Range AWD      Mid-size
# 124        2019  Tesla  Model 3 Long Range AWD Performance      Mid-size
# 160        2020  Tesla                  Model 3 Long Range      Mid-size
# 161        2020  Tesla              Model 3 Long Range AWD      Mid-size
#
#      Motor (kW) Transmission Fuel type  City (kWh/100 km)  \
# 122         211           A1         B               15.3
# 123         335           A1         B               17.4
# 124         358           A1         B               17.4
# 160         211           A1         B               15.3
# 161         335           A1         B               16.9
#
#      Highway (kWh/100 km)  Combined (kWh/100 km)  City (Le/100 km)  \
# 122                  17.0                   16.1               1.7
# ...

# %%
#Filtramos por el modelo del auto
toyota_bz4x = df[(df["Make"] == "Toyota") & (df["Model"].str.contains("bz4x", case=False, na=False) & (df["Model year"] == 2023))]
toyota_bz4x
# Out:
#      Model year    Make     Model                 Vehicle class  Motor (kW)  \
# 460        2023  Toyota      bZ4X  Sport utility vehicle: Small         150
# 461        2023  Toyota  bZ4X AWD  Sport utility vehicle: Small         160
#
#     Transmission Fuel type  City (kWh/100 km)  Highway (kWh/100 km)  \
# 460           A1         B               16.0                  19.5
# 461           A1         B               18.4                  22.3
#
#      Combined (kWh/100 km)  City (Le/100 km)  Highway (Le/100 km)  \
# 460                   17.6               1.8                  2.2
# 461                   20.1               2.1                  2.5
#
#      Combined (Le/100 km)  Range (km)  CO2 emissions (g/km)  CO2 rating   \
# 460                   2.0         406                     0         10.0
# 461                   2.3         367                     0         10.0
#
#      Smog rating  Recharge time (h)
# 460         10.0               11.0
# ...

# %%
#Unimos todos los datos filtrados
autos_permitidos = pd.concat([hyundai_ioniq5, kia_niro, tesla_model3, toyota_bz4x]).reset_index(drop=True)
autos_permitidos["Marca_año_y_modelo"] = autos_permitidos["Model year"].astype(str) + " " + autos_permitidos["Make"].astype(str) + " " + autos_permitidos["Model"].astype(str)

# %%
#Graficamos los modelos con su tiempo de carga
plt.figure(figsize=(10,8))
sns.barplot(data= autos_permitidos, y = "Marca_año_y_modelo", x= "Recharge time (h)")
plt.show()

# %%
#Graficamos los modelos con los kwh que consumen en 100km
plt.figure(figsize=(10,8))
sns.barplot(data= autos_permitidos, y = "Marca_año_y_modelo", x= "City (kWh/100 km)")
plt.show()

# %%
#Graficamos los modelos con la distancia que pueden recorrer
plt.figure(figsize=(10,8))
sns.barplot(data= autos_permitidos, y = "Marca_año_y_modelo", x= "Range (km)")
plt.show()
